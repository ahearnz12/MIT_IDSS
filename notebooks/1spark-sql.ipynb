# %% [markdown]
# # Basic Dataframe code

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.config("spark.some.config.option", "some-value").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/08 16:26:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#json file is in the HDFS(Hue)

# %%
df = spark.read.json('../data/people.json')

# %%
#spark.read.csv('../data/abc.csv')

# %%
df
# Out:
# DataFrame[age: bigint, name: string]

# %%
#DataFrame[age:bigint, name:string]

# %%
df.head()
# Out:
# Row(age=None, name='Michael')

# %%
#Displays the content of the DataFrame to stdout, Very similar to Pandas

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.select("name").show()
# Out:
# +-------+
# |   name|
# +-------+
# |Michael|
# |   Andy|
# | Justin|
# +-------+

# %%
df.select(df['name'], df['age'] +1).show()

# %%
df2 = df.select(df['name'], df['age'] +1)

# %%
df2
# Out:
# DataFrame[name: string, (age + 1): bigint]

# %%
df2.show()
# Out:
# +-------+---------+
# |   name|(age + 1)|
# +-------+---------+
# |Michael|     NULL|
# |   Andy|       31|
# | Justin|       20|
# +-------+---------+

# %%
df.filter(df['age']> 18).show()
# Out:
# +---+------+
# |age|  name|
# +---+------+
# | 30|  Andy|
# | 19|Justin|
# +---+------+

# %%
df.groupBy("age").count().show()
# Out:
# +----+-----+
# | age|count|
# +----+-----+
# |  19|    1|
# |NULL|    1|
# |  30|    1|
# +----+-----+

# %% [markdown]
# # Register the DataFrame as a SQL temporary view

# %%
df.createOrReplaceTempView("people")

# %%
sqlDF = spark.sql("SELECT * FROM people")

# %%
sqlDF
# Out:
# DataFrame[age: bigint, name: string]

# %%
sqlDF.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %% [markdown]
# # Spark context: RDD

# %%
sc = spark.sparkContext

# %%
#Load a text file and convert each line to a Row.
lines = sc.textFile('../data/kmeans_sample.txt')

# %%
#lines.top(1)

# %%
#lines.take(2)

# %%
#parts = lines.map(lambda 1: 1.split(" , "))

# %%
#parts.top(2)

# %% [markdown]
# # programmatic_schema_example

# %%
sc = spark.sparkContext

# %%
" andy "
# Out:
# ' andy '

# %%
#load a text file and convert each line to a Row
lines = sc.textFile('../data/people.txt')
parts = lines.map(lambda l: l.split(" , "))
# Filter out lines that don't have at least two parts
parts = parts.filter(lambda p: len(p) >= 2)
#Each line is converted to a tuple
people = parts.map(lambda p: (p[0], p[1].strip()))
people.top(2)
# Out:
# []

# %%
people.top(2)
# Out:
# []

# %%
people.top(2)
# Out:
# []

# %%
people

# %% [markdown]
# # Need to define schema by providing datatypes of all the columns

# %%
schema = StructType([
	StructField('name', StringType(), True),
	StructField('age', StringType(), True)
])

# %%
#Apply the schema to the RDD
SchemaPeople = spark.createDataFrame(people, schema)

# %%
SchemaPeople.show()
# Out:
# +----+---+
# |name|age|
# +----+---+
# +----+---+

# %%
#creates a temporary view using the DataFrame
SchemaPeople.createOrReplaceTempView("people")

# %%
#SQL can be run over DataFrames that have been registered as a table
results = spark.sql("SELECT name FROM people")

# %%
results.show()
# Out:
# +----+
# |name|
# +----+
# +----+

# %%
spark.stop()
