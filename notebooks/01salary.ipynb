# %% [markdown]
# # count the no of employees in particular salary

# %% [markdown]
# # The file fields are id,name, salary

# %%
import pyspark

# %%
from pyspark import SparkContext

# %%
sc = SparkContext()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/08 16:23:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
input = sc.textFile("../data/emp.txt")

# %%
input
# Out:
# ../data/emp.txt MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %%
input.top(7)
# Out:
# ["'satya',80000",
#  "'sajan',80000",
#  "'elon',70000",
#  "'charlie',70000",
#  "'bob',50000",
#  "'bill',70000",
#  "'alex',100000"]

# %%
salaries = input.map(lambda x: x.split(',')[1])

# %%
salaries.top(2)
# Out:
# ['80000', '80000']

# %%
results = salaries.countByValue()

# %%
results
# Out:
# defaultdict(int, {'100000': 1, '50000': 1, '70000': 3, '80000': 2})

# %%
for sal, count in results.items():
	print(sal + " " + str(count))
# Out:
# 100000 1
# 50000 1
# 70000 3
# 80000 2

# %%
sc.stop()
